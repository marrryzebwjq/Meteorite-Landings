# %%
import pandas as pd
from geopy.geocoders import Nominatim
import pycountry

# Load the CSV file
file_path = '../data/Meteorite_Landings_20240924.csv'
# read only the first 25 rows
df = pd.read_csv(file_path, nrows=25)

df
# Out:
#                    name   id nametype       recclass  mass (g)  fall  year  \
# 0                Aachen    1    Valid             L5      21.0  Fell  1880
# 1                Aarhus    2    Valid             H6     720.0  Fell  1951
# 2                  Abee    6    Valid            EH4  107000.0  Fell  1952
# 3              Acapulco   10    Valid    Acapulcoite    1914.0  Fell  1976
# 4               Achiras  370    Valid             L6     780.0  Fell  1902
# 5              Adhi Kot  379    Valid            EH4    4239.0  Fell  1919
# 6   Adzhi-Bogdo (stone)  390    Valid          LL3-6     910.0  Fell  1949
# 7                  Agen  392    Valid             H5   30000.0  Fell  1814
# 8                Aguada  398    Valid             L6    1620.0  Fell  1930
# 9         Aguila Blanca  417    Valid              L    1440.0  Fell  1920
# 10     Aioun el Atrouss  423    Valid   Diogenite-pm    1000.0  Fell  1974
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="http")

# for each line of the dataframe, get the country code
def get_country_code(row):
    location = geolocator.reverse(f"{row['reclat']}, {row['reclong']}") # take the latitude and longitude and get the location
    try:
        tmp = location.raw.get('address').get('country_code') # get the country code from the location
    except:
        tmp = None
    
    print(tmp)
    return tmp
    

df['country_code'] = df.apply(get_country_code, axis=1) # apply the function to the dataframe
df
# Out:
# de
# dk
# ca
# mx
# ar
# pk
# mn
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\PycharmProjects\projet_dana_web_semantique\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\PycharmProjects\projet_dana_web_semantique\venv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File C:\Program Files\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
# ...

# %%
# Read the entire CSV file
df_full = pd.read_csv(file_path)

# Apply the get_country_code function to the entire dataframe
df_full['country_code'] = df_full.apply(get_country_code, axis=1)


# Save the dataframe to a new CSV file
df_full.to_csv('../data/Meteorite_Landings_20240924_processed.csv', index=False)
# Out:
# de
# dk
# ca
# mx
# ar
# pk
# mn
# fr
# ar
# ar
# mr
# ne
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\PycharmProjects\projet_dana_web_semantique\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\PycharmProjects\projet_dana_web_semantique\venv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File C:\Program Files\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# ...

# %%
# Initialize the geolocator
geolocator = Nominatim(user_agent="http")

# Define the function to get the country code
def get_country_code(row):
    try:
        # Ensure the coordinates are formatted correctly
        coordinates = f"{row['reclat']}, {row['reclong']}"
        location = geolocator.reverse(coordinates)
        return location.raw.get('address').get('country_code')
    except Exception as e:
        print(f"Error processing row {row.name}: {e}",  f"{row['reclat']}, {row['reclong']}")
        return None
    
# Function to get the country name from the country code
def get_country_name(country_code):
    try:
        return pycountry.countries.get(alpha_2=country_code).name
    except:
        return None


# Load the CSV file
file_path = '../data/Meteorite_Landings_20240924.csv'
df_full = pd.read_csv(file_path, nrows=200)

# Apply the get_country_code function to the entire dataframe
df_full['country_code'] = df_full.apply(get_country_code, axis=1)

# Apply the function to create a new column 'country'
df_full['country'] = df_full['country_code'].apply(get_country_name)

# Save the dataframe to a new CSV file
df_full.to_csv('../data/Meteorite_Landings_20240924_200processed.csv', index=False)
# Out:
# Error processing row 6: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=44.83333&lon=95.16667&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")) 44.83333, 95.16667
# Error processing row 18: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=13.66033&lon=28.96&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")) 13.66033, 28.96
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Program Files\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
# ...
