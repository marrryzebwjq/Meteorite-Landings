# %%
import pandas as pd

# Load the CSV file
file_path = '../data/Meteorite_Landings_20240924.csv'
# read only the first 25 rows
df = pd.read_csv(file_path, nrows=25)

df
# Out:
#                    name   id nametype       recclass  mass (g)  fall  year  \
# 0                Aachen    1    Valid             L5      21.0  Fell  1880
# 1                Aarhus    2    Valid             H6     720.0  Fell  1951
# 2                  Abee    6    Valid            EH4  107000.0  Fell  1952
# 3              Acapulco   10    Valid    Acapulcoite    1914.0  Fell  1976
# 4               Achiras  370    Valid             L6     780.0  Fell  1902
# 5              Adhi Kot  379    Valid            EH4    4239.0  Fell  1919
# 6   Adzhi-Bogdo (stone)  390    Valid          LL3-6     910.0  Fell  1949
# 7                  Agen  392    Valid             H5   30000.0  Fell  1814
# 8                Aguada  398    Valid             L6    1620.0  Fell  1930
# 9         Aguila Blanca  417    Valid              L    1440.0  Fell  1920
# 10     Aioun el Atrouss  423    Valid   Diogenite-pm    1000.0  Fell  1974
# 11                  Aïr  424    Valid             L6   24000.0  Fell  1925
# 12      Aire-sur-la-Lys  425    Valid        Unknown       NaN  Fell  1769
# 13                Akaba  426    Valid             L6     779.0  Fell  1949
# 14             Akbarpur  427    Valid             H4    1800.0  Fell  1838
# 15              Akwanga  432    Valid              H    3000.0  Fell  1959
# 16              Akyumak  433    Valid      Iron, IVA   50000.0  Fell  1981
# 17              Al Rais  446    Valid         CR2-an     160.0  Fell  1957
# 18            Al Zarnkh  447    Valid            LL5     700.0  Fell  2001
# 19                Alais  448    Valid            CI1    6000.0  Fell  1806
# 20             Albareto  453    Valid          L/LL4    2000.0  Fell  1766
# 21              Alberta  454    Valid              L     625.0  Fell  1949
# 22      Alby sur Chéran  458    Valid  Eucrite-mmict     252.0  Fell  2002
# 23            Aldsworth  461    Valid            LL5     700.0  Fell  1835
# 24               Aleppo  462    Valid             L6    3200.0  Fell  1873
#
#       reclat    reclong           GeoLocation
# 0   50.77500    6.08333     (50.775, 6.08333)
# 1   56.18333   10.23333  (56.18333, 10.23333)
# 2   54.21667 -113.00000    (54.21667, -113.0)
# 3   16.88333  -99.90000     (16.88333, -99.9)
# 4  -33.16667  -64.95000   (-33.16667, -64.95)
# 5   32.10000   71.80000          (32.1, 71.8)
# 6   44.83333   95.16667  (44.83333, 95.16667)
# 7   44.21667    0.61667   (44.21667, 0.61667)
# 8  -31.60000  -65.23333    (-31.6, -65.23333)
# 9  -30.86667  -64.55000   (-30.86667, -64.55)
# 10  16.39806   -9.57028  (16.39806, -9.57028)
# 11  19.08333    8.38333   (19.08333, 8.38333)
# 12  50.66667    2.33333   (50.66667, 2.33333)
# 13  29.51667   35.05000     (29.51667, 35.05)
# 14  29.71667   77.95000     (29.71667, 77.95)
# 15   8.91667    8.43333    (8.91667, 8.43333)
# 16  39.91667   42.81667  (39.91667, 42.81667)
# 17  24.41667   39.51667  (24.41667, 39.51667)
# 18  13.66033   28.96000     (13.66033, 28.96)
# 19  44.11667    4.08333   (44.11667, 4.08333)
# 20  44.65000   11.01667     (44.65, 11.01667)
# 21   2.00000   22.66667       (2.0, 22.66667)
# 22  45.82133    6.01533   (45.82133, 6.01533)
# 23  51.78333   -1.78333  (51.78333, -1.78333)
# 24  36.23333   37.13333  (36.23333, 37.13333)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="http")

# for each line of the dataframe, get the country code
def get_country_code(row):
    location = geolocator.reverse(f"{row['reclat']}, {row['reclong']}") # take the latitude and longitude and get the location
    try:
        tmp = location.raw.get('address').get('country_code') # get the country code from the location
    except:
        tmp = None
    
    print(tmp)
    return tmp
    

df['country_code'] = df.apply(get_country_code, axis=1) # apply the function to the dataframe
df
# Out:
# de
# dk
# ca
# mx
# ar
# pk
# mn
# fr
# ar
# ar
# mr
# ne
# fr
# jo
# in
# ng
# tr
# sa
# sd
# fr
# it
# cd
# fr
# gb
# sy
#                    name   id nametype       recclass  mass (g)  fall  year  \
# 0                Aachen    1    Valid             L5      21.0  Fell  1880
# 1                Aarhus    2    Valid             H6     720.0  Fell  1951
# 2                  Abee    6    Valid            EH4  107000.0  Fell  1952
# 3              Acapulco   10    Valid    Acapulcoite    1914.0  Fell  1976
# 4               Achiras  370    Valid             L6     780.0  Fell  1902
# 5              Adhi Kot  379    Valid            EH4    4239.0  Fell  1919
# 6   Adzhi-Bogdo (stone)  390    Valid          LL3-6     910.0  Fell  1949
# 7                  Agen  392    Valid             H5   30000.0  Fell  1814
# 8                Aguada  398    Valid             L6    1620.0  Fell  1930
# 9         Aguila Blanca  417    Valid              L    1440.0  Fell  1920
# 10     Aioun el Atrouss  423    Valid   Diogenite-pm    1000.0  Fell  1974
# 11                  Aïr  424    Valid             L6   24000.0  Fell  1925
# 12      Aire-sur-la-Lys  425    Valid        Unknown       NaN  Fell  1769
# 13                Akaba  426    Valid             L6     779.0  Fell  1949
# 14             Akbarpur  427    Valid             H4    1800.0  Fell  1838
# 15              Akwanga  432    Valid              H    3000.0  Fell  1959
# 16              Akyumak  433    Valid      Iron, IVA   50000.0  Fell  1981
# 17              Al Rais  446    Valid         CR2-an     160.0  Fell  1957
# 18            Al Zarnkh  447    Valid            LL5     700.0  Fell  2001
# 19                Alais  448    Valid            CI1    6000.0  Fell  1806
# 20             Albareto  453    Valid          L/LL4    2000.0  Fell  1766
# 21              Alberta  454    Valid              L     625.0  Fell  1949
# 22      Alby sur Chéran  458    Valid  Eucrite-mmict     252.0  Fell  2002
# 23            Aldsworth  461    Valid            LL5     700.0  Fell  1835
# 24               Aleppo  462    Valid             L6    3200.0  Fell  1873
#
#       reclat    reclong           GeoLocation country_code
# 0   50.77500    6.08333     (50.775, 6.08333)           de
# 1   56.18333   10.23333  (56.18333, 10.23333)           dk
# 2   54.21667 -113.00000    (54.21667, -113.0)           ca
# 3   16.88333  -99.90000     (16.88333, -99.9)           mx
# 4  -33.16667  -64.95000   (-33.16667, -64.95)           ar
# 5   32.10000   71.80000          (32.1, 71.8)           pk
# 6   44.83333   95.16667  (44.83333, 95.16667)           mn
# 7   44.21667    0.61667   (44.21667, 0.61667)           fr
# 8  -31.60000  -65.23333    (-31.6, -65.23333)           ar
# 9  -30.86667  -64.55000   (-30.86667, -64.55)           ar
# 10  16.39806   -9.57028  (16.39806, -9.57028)           mr
# 11  19.08333    8.38333   (19.08333, 8.38333)           ne
# 12  50.66667    2.33333   (50.66667, 2.33333)           fr
# 13  29.51667   35.05000     (29.51667, 35.05)           jo
# 14  29.71667   77.95000     (29.71667, 77.95)           in
# 15   8.91667    8.43333    (8.91667, 8.43333)           ng
# 16  39.91667   42.81667  (39.91667, 42.81667)           tr
# 17  24.41667   39.51667  (24.41667, 39.51667)           sa
# 18  13.66033   28.96000     (13.66033, 28.96)           sd
# 19  44.11667    4.08333   (44.11667, 4.08333)           fr
# 20  44.65000   11.01667     (44.65, 11.01667)           it
# 21   2.00000   22.66667       (2.0, 22.66667)           cd
# 22  45.82133    6.01533   (45.82133, 6.01533)           fr
# 23  51.78333   -1.78333  (51.78333, -1.78333)           gb
# 24  36.23333   37.13333  (36.23333, 37.13333)           sy

# %%
# Read the entire CSV file
df_full = pd.read_csv(file_path)

# Apply the get_country_code function to the entire dataframe
df_full['country_code'] = df_full.apply(get_country_code, axis=1)


# Save the dataframe to a new CSV file
df_full.to_csv('../data/Meteorite_Landings_20240924_processed.csv', index=False)
# Out:
# de
# dk
# ca
# mx
# ar
# pk
# mn
# fr
# ar
# ar
# mr
# ne
# fr
# jo
# in
# ng
# tr
# sa
# sd
# fr
# it
# cd
# fr
# gb
# sy
# it
# ua
# it
# us
# mx
# sd
# iq
# in
# in
# us
# ua
# in
# None
# fr
# br
# et
# cn
# jp
# gb
# fr
# ar
# us
# ar
# fr
# us
# gb
# it
# in
# mx
# us
# us
# fr
# dz
# fr
# fr
# br
# si
# mx
# ug
# us
# ua
# in
# us
# us
# cf
# th
# id
# in
# in
# id
# fr
# es
# es
# ru
# de
# in
# gb
# mr
# pl
# us
# us
# us
# gh
# us
# us
# ca
# gb
# us
# ar
# in
# ma
# tn
# us
# za
# ma
# ca
# ar
# bf
# es
# us
# us
# fr
# lb
# in
# in
# in
# bd
# in
# pl
# ua
# bf
# au
# ng
# us
# in
# ua
# fi
# us
# us
# us
# cz
# us
# cn
# mx
# bf
# ru
# it
# in
# ru
# ua
# ru
# ua
# mr
# mr
# gb
# us
# cz
# de
# de
# ru
# ca
# uz
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:350, in Nominatim.reverse(self, query, exactly_one, timeout, language, addressdetails, zoom, namedetails)
#     349 try:
# --> 350     lat, lon = self._coerce_point_to_string(query).split(',')
#     351 except ValueError:
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:300, in Geocoder._coerce_point_to_string(self, point, output_format)
#     299 if not isinstance(point, Point):
# --> 300     point = Point(point)
#     302 # Altitude is silently dropped.
#     303 #
#     304 # Geocoding services (almost?) always consider only lat and lon
#    (...)
#     307 # though, because PoIs are assumed to span the whole
#     308 # altitude axis (i.e. not just the 0km plane).
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\point.py:166, in Point.__new__(cls, latitude, longitude, altitude)
#     165 elif isinstance(arg, str):
# --> 166     return cls.from_string(arg)
#     167 else:
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\point.py:457, in Point.from_string(cls, string)
#     456 else:
# --> 457     raise ValueError(
#     458         "Failed to create Point instance from string: unknown format."
#     459     )
#
# ValueError: Failed to create Point instance from string: unknown format.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [9], in <module>
#       2 df_full = pd.read_csv(file_path)
#       4 # Apply the get_country_code function to the entire dataframe
# ----> 5 df_full['country_code'] = df_full.apply(get_country_code, axis=1)
#       8 # Save the dataframe to a new CSV file
#       9 df_full.to_csv('../data/Meteorite_Landings_20240924_processed.csv', index=False)
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [8], in get_country_code(row)
#       5 def get_country_code(row):
# ----> 6     location = geolocator.reverse(f"{row['reclat']}, {row['reclong']}") # take the latitude and longitude and get the location
#       7     try:
#       8         tmp = location.raw.get('address').get('country_code') # get the country code from the location
#
# File c:\Users\gab20\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:352, in Nominatim.reverse(self, query, exactly_one, timeout, language, addressdetails, zoom, namedetails)
#     350     lat, lon = self._coerce_point_to_string(query).split(',')
#     351 except ValueError:
# --> 352     raise ValueError("Must be a coordinate pair or Point")
#     353 params = {
#     354     'lat': lat,
#     355     'lon': lon,
#     356     'format': 'json',
#     357 }
#     358 if language:
#
# ValueError: Must be a coordinate pair or Point

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Initialize the geolocator
geolocator = Nominatim(user_agent="http")

# Define the function to get the country code
def get_country_code(row):
    try:
        # Ensure the coordinates are formatted correctly
        coordinates = f"{row['reclat']}, {row['reclong']}"
        location = geolocator.reverse(coordinates)
        return location.raw.get('address').get('country_code')
    except Exception as e:
        print(f"Error processing row {row.name}: {e}",  f"{row['reclat']}, {row['reclong']}")
        return None

# Load the CSV file
file_path = '../data/Meteorite_Landings_20240924.csv'
df_full = pd.read_csv(file_path, nrows=200)

# Apply the get_country_code function to the entire dataframe
df_full['country_code'] = df_full.apply(get_country_code, axis=1)

# Save the dataframe to a new CSV file
df_full.to_csv('../data/Meteorite_Landings_20240924_processed.csv', index=False)
# Out:
# Error processing row 37: 'NoneType' object has no attribute 'raw' 0.0, 0.0
# Error processing row 147: Must be a coordinate pair or Point nan, nan
